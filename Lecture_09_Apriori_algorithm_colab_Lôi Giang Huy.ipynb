# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
sys.path.append('drive/My Drive')

# %%
import numpy as np
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# %% [markdown]
# ### Data preparation

# %% [markdown]
# #### Load data

# %%
data = pd.read_excel('drive/My Drive/Colab Notebooks/My Drive/Online Retail.xlsx')

# %% [markdown]
# #### Explore data

# %%
data.head()
# Out:
#   InvoiceNo StockCode  ... CustomerID         Country
# 0    536365    85123A  ...    17850.0  United Kingdom
# 1    536365     71053  ...    17850.0  United Kingdom
# 2    536365    84406B  ...    17850.0  United Kingdom
# 3    536365    84029G  ...    17850.0  United Kingdom
# 4    536365    84029E  ...    17850.0  United Kingdom
#
# [5 rows x 8 columns]

# %%
# Explore the columns of the data
data.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
data.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
# Explore different regions of transactions
data.Country.unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# #### Data cleaning and transformation

# %%
# Strip extra spaces in the description
data['Description'] = data['Description'].str.strip()

# %%
# Drop the rows without any invoice number
data.dropna(axis = 0, subset =['InvoiceNo'], inplace = True)
data['InvoiceNo'] = data['InvoiceNo'].astype('str')

# %%
# Remove the cancelled transactions (those transactions containing 'C')
data = data[~data['InvoiceNo'].str.contains('C')]

# %% [markdown]
# <b>Note: </b> Tilde (~) means negation, i.e in this case, InvoiceNo that DON'T contains C

# %%
# Define one-hot encoding function to make the data suitable for calculation. 
# For one-hot encoding, only there exist 0 and 1 in the fields. Make all positive values are 1 and others are 0
def onehot_encode(x):
    try:
        x = float(x)
    except ValueError:
        print('Not a number')
    if x <= 0:
        return 0
    else:
        return 1

# %% [markdown]
# ### Mining Association Rules

# %% [markdown]
# ##### France

# %%
# Transactions done in France
basket_France = (data[data['Country'] =="France"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
# Encoding the datasets
basket_France = basket_France.applymap(onehot_encode)

# %%
# Mining Frequent itemsets
frq_items = apriori(basket_France, min_support = 0.05, use_colnames = True)
  
# Mining strong association rules
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
rules.head(10)
# Out:
#                                            antecedents  ... conviction
# 44                        (JUMBO BAG WOODLAND ANIMALS)  ...        inf
# 258  (RED TOADSTOOL LED NIGHT LIGHT, PLASTERS IN TI...  ...        inf
# 271  (RED TOADSTOOL LED NIGHT LIGHT, PLASTERS IN TI...  ...        inf
# 302  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETRO...  ...  34.897959
# 301  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...  ...  34.489796
# 337  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETRO...  ...  28.790816
# 335  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...  ...  28.454082
# 129                         (RED RETROSPOT PICNIC BAG)  ...   6.571429
# 143                    (SET OF 9 BLACK SKULL BALLOONS)  ...   6.102041
# 174                    (SET/6 RED SPOTTY PAPER PLATES)  ...  21.556122
#
# [10 rows x 9 columns]

# %% [markdown]
# <b> Comments: </b><br>
# From the above output, it can be seen that paper cups and paper and plates are bought together in France. This is because the French have a culture of having a get-together with their friends and family atleast once a week. Also, since the French government has banned the use of plastic in the country, the people have to purchase the paper -based alternatives.

# %% [markdown]
# ##### UK

# %%
# Transactions done in United Kingdom
basket_UK = (data[data['Country'] =="United Kingdom"]
          .groupby(['InvoiceNo', 'Description'])['Quantity'].sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
# Encoding the datasets
basket_UK = basket_UK.applymap(onehot_encode)

# %%
# Mining Frequent itemsets
frq_items = apriori(basket_UK, min_support = 0.01, use_colnames = True)
  
# Mining strong association rules
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
rules.head(10)
# Out:
#                                             antecedents  ... conviction
# 116                (BEADED CRYSTAL HEART PINK ON STICK)  ...  39.637371
# 2018       (SUKI  SHOULDER BAG, JAM MAKING SET PRINTED)  ...  26.096206
# 2295              (HERB MARKER THYME, HERB MARKER MINT)  ...  21.947227
# 2302        (HERB MARKER PARSLEY, HERB MARKER ROSEMARY)  ...  20.444951
# 2300           (HERB MARKER PARSLEY, HERB MARKER THYME)  ...  20.443842
# 2276             (HERB MARKER BASIL, HERB MARKER THYME)  ...  20.048792
# 3357  (REGENCY TEA PLATE PINK, REGENCY TEA PLATE ROSES)  ...  17.827083
# 3375  (WOODEN TREE CHRISTMAS SCANDINAVIAN, WOODEN HE...  ...  17.388217
# 2290              (HERB MARKER THYME, HERB MARKER MINT)  ...  16.463099
# 2278          (HERB MARKER BASIL, HERB MARKER ROSEMARY)  ...  15.650910
#
# [10 rows x 9 columns]

# %% [markdown]
# <b> Comments: </b><br>
# Thyme, Rosemary, Mint,... are used for tea. That means, British people buy many kind of herbal tea. Furthermore, they often buy different colored tea-plates together. A reason behind this may be because typically the British enjoy tea very much and often collect different colored tea-plates for different occasions.

# %% [markdown]
# ##### Sweden

# %%
# Transactions done in Sweden
basket_Sweden = (data[data['Country'] =="Sweden"]
          .groupby(['InvoiceNo', 'Description'])['Quantity'].sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
# Encoding the datasets
basket_Sweden = basket_Sweden.applymap(onehot_encode)

# %%
# Mining Frequent itemsets
frq_items = apriori(basket_Sweden, min_support = 0.05, use_colnames = True)
  
# Mining strong association rules
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
rules.head(10)
# Out:
#                               antecedents  ... conviction
# 0           (12 PENCILS SMALL TUBE SKULL)  ...        inf
# 1           (PACK OF 72 SKULL CAKE CASES)  ...        inf
# 4                 (36 DOILIES DOLLY GIRL)  ...        inf
# 5          (ASSORTED BOTTLE TOP  MAGNETS)  ...        inf
# 180        (CHILDRENS CUTLERY DOLLY GIRL)  ...        inf
# 181     (CHILDRENS CUTLERY CIRCUS PARADE)  ...        inf
# 212               (MOBILE VINTAGE HEARTS)  ...        inf
# 213  (FAIRY CAKE FLANNEL ASSORTED COLOUR)  ...        inf
# 216                       (FIRST AID TIN)  ...        inf
# 217             (PHARMACIE FIRST AID TIN)  ...        inf
#
# [10 rows x 9 columns]

# %% [markdown]
# <b> Comments: </b><br>
# On analyzing the above rules, it is found that boys’ and girls’ cutlery are paired together. This makes practical sense because when a parent goes shopping for cutlery for his/her children, he/she would want the product to be a little customized according to the kid’s wishes.

# %% [markdown]
# #####  Portugal

# %%
# Transactions done in Portugal
basket_Portugal = (data[data['Country'] =="Portugal"]
          .groupby(['InvoiceNo', 'Description'])['Quantity'].sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
# Encoding the datasets
basket_Portugal = basket_Portugal.applymap(onehot_encode)

# %%
# Mining Frequent itemsets
frq_items = apriori(basket_Portugal, min_support = 0.05, use_colnames = True)
  
# Mining strong association rules
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
rules.head(10)
# Out:
#                               antecedents  ... conviction
# 1170   (SET 12 COLOUR PENCILS DOLLY GIRL)  ...        inf
# 1171     (SET 12 COLOUR PENCILS SPACEBOY)  ...        inf
# 1172   (SET OF 4 KNICK KNACK TINS LONDON)  ...        inf
# 1173   (SET 12 COLOUR PENCILS DOLLY GIRL)  ...        inf
# 1174   (SET 12 COLOUR PENCILS DOLLY GIRL)  ...        inf
# 1175  (SET OF 4 KNICK KNACK TINS POPPIES)  ...        inf
# 1176   (SET OF 4 KNICK KNACK TINS LONDON)  ...        inf
# 1177     (SET 12 COLOUR PENCILS SPACEBOY)  ...        inf
# 1178     (SET 12 COLOUR PENCILS SPACEBOY)  ...        inf
# 1179  (SET OF 4 KNICK KNACK TINS POPPIES)  ...        inf
#
# [10 rows x 9 columns]

# %% [markdown]
# <b> Comments: </b><br>
# On analyzing the association rules for Portuguese transactions, it is observed that Tiffin sets (Knick Knack Tins) and color pencils. These two products typically belong to a primary school going kid. These two products are required by children in school to carry their lunch and for creative work respectively and hence are logically make sense to be paired together.

# %% [markdown]
# ##### Canada

# %%
# Transactions done in Canada
basket_Canada = (data[data['Country'] =="Canada"]
          .groupby(['InvoiceNo', 'Description'])['Quantity'].sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
# Encoding the datasets
basket_Canada = basket_Canada.applymap(onehot_encode)

# %%
# Mining Frequent itemsets
frq_items = apriori(basket_Canada, min_support = 0.05, use_colnames = True)
  
# Mining strong association rules
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
rules.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-9f285af8f2c6> in <module>()
#       1 # Mining Frequent itemsets
# ----> 2 frq_items = apriori(basket_Canada, min_support = 0.07, use_colnames = True)
#       3
#       4 # Mining strong association rules
#       5 rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
#
# /usr/local/lib/python3.7/dist-packages/mlxtend/frequent_patterns/apriori.py in apriori(df, min_support, use_colnames, max_len, n_jobs)
#     140                 together = np.all(X[:, c] == all_ones, axis=1)
#     141             else:
# --> 142                 together = X[:, c].all(axis=1)
#     143             support = together.sum() / rows_count
#     144             if support >= min_support:
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py in _all(a, axis, dtype, out, keepdims)
#      55
#      56 def _all(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 57     return umr_all(a, axis, dtype, out, keepdims)
#      58
#      59 def _count_reduce_items(arr, axis):
#
# KeyboardInterrupt:

# %% [markdown]
# <b> Comments: </b><br>
# From the above output, it can be seen that paper cups and paper and plates are bought together in France. This is because the French have a culture of having a get-together with their friends and family atleast once a week. Also, since the French government has banned the use of plastic in the country, the people have to purchase the paper -based alternatives.

# %% [markdown]
# ##### Australia

# %%
# Transactions done in Australia
basket_Australia = (data[data['Country'] =="Australia"]
          .groupby(['InvoiceNo', 'Description'])['Quantity'].sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
# Encoding the datasets
basket_Australia = basket_Australia.applymap(onehot_encode)

# %%
# Mining Frequent itemsets
frq_items = apriori(basket_Australia, min_support = 0.05, use_colnames = True)
  
# Mining strong association rules
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
rules.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-a55cb3d605cb> in <module>()
#       3
#       4 # Mining strong association rules
# ----> 5 rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
#       6 rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
#       7 rules.head(10)
#
# /usr/local/lib/python3.7/dist-packages/mlxtend/frequent_patterns/association_rules.py in association_rules(df, metric, min_threshold, support_only)
#     142             for c in combinations(k, r=idx):
#     143                 antecedent = frozenset(c)
# --> 144                 consequent = k.difference(antecedent)
#     145
#     146                 if support_only:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Take-home assignment

# %% [markdown]
# Carry out similar analyses for the remaining countries
